# %%
import pandas as pd
import numpy as np
df = pd.read_csv("test_data.csv",encoding='utf-8',sep = '\s+',error_bad_lines=False)
df.head()
# Out:
# b'Skipping line 59: expected 15 fields, saw 16\nSkipping line 112: expected 15 fields, saw 16\n'
#            city country first_name     home_town  last_name  \
# 0  Екатеринбург  Россия      Данил  Екатеринбург  Отдельнов
# 1        Москва  Россия      Мария        Москва  Сметанина
# 2        Москва  Россия      Стёпа       Севагин      False
# 3        Москва  Россия       Иван      Чумачков      False
# 4        Москва  Россия  Anastasia     Biryukova       True
#
#   in_hse_memes_group     wall_repost_cnt      wall_like_mean political_cat  \
# 0              False               182.0  1.8814279643008924          14.0
# 1               True                 0.0                   0             0
# 2                0.0  25.285714285714285                 0.0             1
# 3                2.0   5.217391304347826                 4.0             1
# 4                0.0   21.33333333333333                 0.0             1
#
# ...
